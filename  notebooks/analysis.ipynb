# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🏍️ FIPE Analysis Notebook\n",
    "Análise dos dados de motos FIPE coletados e armazenados nas camadas Bronze, Silver e Gold."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Imports\n",
    "import psycopg2\n",
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "\n",
    "sns.set(style=\"whitegrid\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1️⃣ Conexão com o banco PostgreSQL"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "DB_HOST = \"localhost\"\n",
    "DB_PORT = 5432\n",
    "DB_NAME = \"fipe_banco\"\n",
    "DB_USER = \"postgres\"\n",
    "DB_PASS = \"postgres\"\n",
    "\n",
    "conn = psycopg2.connect(\n",
    "    host=DB_HOST,\n",
    "    port=DB_PORT,\n",
    "    dbname=DB_NAME,\n",
    "    user=DB_USER,\n",
    "    password=DB_PASS\n",
    ")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2️⃣ Carregar dados das camadas"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Bronze\n",
    "df_bronze = pd.read_sql(\"SELECT * FROM bronze.fipe_raw\", conn)\n",
    "df_bronze.head()"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Silver\n",
    "df_silver = pd.read_sql(\"SELECT * FROM silver.fipe_limited\", conn)\n",
    "df_silver.head()"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Gold\n",
    "df_gold = pd.read_sql(\"SELECT * FROM gold.fipe_summary\", conn)\n",
    "df_gold.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3️⃣ Estatísticas Descritivas"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "print(\"### Bronze\")\n",
    "print(df_bronze.describe(include='all'))\n",
    "\n",
    "print(\"\\n### Silver\")\n",
    "print(df_silver.describe(include='all'))\n",
    "\n",
    "print(\"\\n### Gold\")\n",
    "print(df_gold.describe(include='all'))"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4️⃣ Gráficos e Visualizações"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Top 10 motos mais caras na faixa Silver\n",
    "top10 = df_silver.sort_values('valor_numeric', ascending=False).head(10)\n",
    "\n",
    "plt.figure(figsize=(12,6))\n",
    "sns.barplot(x='modelo', y='valor_numeric', hue='marca', data=top10)\n",
    "plt.title('Top 10 Motos FIPE — Faixa 18k a 30k')\n",
    "plt.xticks(rotation=45, ha='right')\n",
    "plt.ylabel('Valor (R$)')\n",
    "plt.xlabel('Modelo')\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Média de valor por marca (Gold)\n",
    "plt.figure(figsize=(8,5))\n",
    "sns.barplot(x='marca', y='media_valor', data=df_gold)\n",
    "plt.title('Média de Valor por Marca')\n",
    "plt.ylabel('Valor Médio (R$)')\n",
    "plt.xlabel('Marca')\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Distribuição de valores (Silver)\n",
    "plt.figure(figsize=(10,5))\n",
    "sns.histplot(df_silver['valor_numeric'], bins=20, kde=True)\n",
    "plt.title('Distribuição de Valores — Silver')\n",
    "plt.xlabel('Valor (R$)')\n",
    "plt.ylabel('Quantidade')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5️⃣ Exportar CSVs (opcional)"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "df_bronze.to_csv('datasets/bronze_fipe.csv', index=False, encoding='utf-8')\n",
    "df_silver.to_csv('datasets/silver_fipe.csv', index=False, encoding='utf-8')\n",
    "df_gold.to_csv('datasets/gold_fipe.csv', index=False, encoding='utf-8')\n",
    "\n",
    "print('CSV exportados em datasets/')"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.12"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 66
#      63     print(silver_data[['price', 'quantity', 'total_sales']].describe())
#      65 if __name__ == "__main__":
# ---> 66     exploratory_analysis()
#
# Cell In[2], line 19, in exploratory_analysis()
#      16 """Análise exploratória dos dados processados"""
#      18 # 1. Vendas Mensais
# ---> 19 monthly_sales = pd.read_sql("SELECT * FROM gold.vw_monthly_sales_dashboard", engine)
#      21 plt.figure(figsize=(12, 6))
#      22 plt.plot(
#      23     monthly_sales['year'].astype(str) + '-' + monthly_sales['month'].astype(str).str.zfill(2),
#      24     monthly_sales['monthly_revenue'],
#      25     marker='o'
#      26 )
#
# ...
